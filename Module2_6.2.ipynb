# %%
#Assign Values
guess_me = 7
number = 1

#while loop
while True:
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break #exit loop
    else number > guess_me
        print("oops")
        break exit loop

#increment number
number + = 1
