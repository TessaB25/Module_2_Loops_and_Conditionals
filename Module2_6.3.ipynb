# %%
#Assign Values
#Assign Value
guess_me = 5

#For Loop Over Range(10)
for number in range(10)
   if number < guess_me:
       print("too low")
   elif number == guess_me:
       print("found it!")
       break exit the loop
    else: number > guess_me
        print("oops")
        break exit the loop
