# %%
#Assign numbers
secret = 7 #choose any number between 1 and 10
guess = 5 # choose another number between 1 and 10

#Conditional tests
if guess < secret:
    print("too low")
elif guess > secret:
    print("too high")
else:
    print("just right")
