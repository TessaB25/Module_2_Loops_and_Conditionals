# %%
#Assign True/False Values
small = True
green = False

#Check which item matches the characteristics
if small and green:
    print("pea")
elif small and not green:
    print("cherry")
elif not small and green:
    print("watermelon")
else: not small and not green
    print("pumpkin")
